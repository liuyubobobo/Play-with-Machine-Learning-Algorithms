# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.data
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
#        [ 5.2,  3.4,  1.4,  0.2],
#        [ 4.7,  3.2,  1.6,  0.2],
#        [ 4.8,  3.1,  1.6,  0.2],
#        [ 5.4,  3.4,  1.5,  0.4],
#        [ 5.2,  4.1,  1.5,  0.1],
#        [ 5.5,  4.2,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5. ,  3.2,  1.2,  0.2],
#        [ 5.5,  3.5,  1.3,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 4.4,  3. ,  1.3,  0.2],
#        [ 5.1,  3.4,  1.5,  0.2],
#        [ 5. ,  3.5,  1.3,  0.3],
#        [ 4.5,  2.3,  1.3,  0.3],
#        [ 4.4,  3.2,  1.3,  0.2],
#        [ 5. ,  3.5,  1.6,  0.6],
#        [ 5.1,  3.8,  1.9,  0.4],
#        [ 4.8,  3. ,  1.4,  0.3],
#        [ 5.1,  3.8,  1.6,  0.2],
#        [ 4.6,  3.2,  1.4,  0.2],
#        [ 5.3,  3.7,  1.5,  0.2],
#        [ 5. ,  3.3,  1.4,  0.2],
#        [ 7. ,  3.2,  4.7,  1.4],
#        [ 6.4,  3.2,  4.5,  1.5],
#        [ 6.9,  3.1,  4.9,  1.5],
#        [ 5.5,  2.3,  4. ,  1.3],
#        [ 6.5,  2.8,  4.6,  1.5],
#        [ 5.7,  2.8,  4.5,  1.3],
#        [ 6.3,  3.3,  4.7,  1.6],
#        [ 4.9,  2.4,  3.3,  1. ],
#        [ 6.6,  2.9,  4.6,  1.3],
#        [ 5.2,  2.7,  3.9,  1.4],
#        [ 5. ,  2. ,  3.5,  1. ],
#        [ 5.9,  3. ,  4.2,  1.5],
#        [ 6. ,  2.2,  4. ,  1. ],
#        [ 6.1,  2.9,  4.7,  1.4],
#        [ 5.6,  2.9,  3.6,  1.3],
#        [ 6.7,  3.1,  4.4,  1.4],
#        [ 5.6,  3. ,  4.5,  1.5],
#        [ 5.8,  2.7,  4.1,  1. ],
#        [ 6.2,  2.2,  4.5,  1.5],
#        [ 5.6,  2.5,  3.9,  1.1],
#        [ 5.9,  3.2,  4.8,  1.8],
#        [ 6.1,  2.8,  4. ,  1.3],
#        [ 6.3,  2.5,  4.9,  1.5],
#        [ 6.1,  2.8,  4.7,  1.2],
#        [ 6.4,  2.9,  4.3,  1.3],
#        [ 6.6,  3. ,  4.4,  1.4],
#        [ 6.8,  2.8,  4.8,  1.4],
#        [ 6.7,  3. ,  5. ,  1.7],
#        [ 6. ,  2.9,  4.5,  1.5],
#        [ 5.7,  2.6,  3.5,  1. ],
#        [ 5.5,  2.4,  3.8,  1.1],
#        [ 5.5,  2.4,  3.7,  1. ],
#        [ 5.8,  2.7,  3.9,  1.2],
#        [ 6. ,  2.7,  5.1,  1.6],
#        [ 5.4,  3. ,  4.5,  1.5],
#        [ 6. ,  3.4,  4.5,  1.6],
#        [ 6.7,  3.1,  4.7,  1.5],
#        [ 6.3,  2.3,  4.4,  1.3],
#        [ 5.6,  3. ,  4.1,  1.3],
#        [ 5.5,  2.5,  4. ,  1.3],
#        [ 5.5,  2.6,  4.4,  1.2],
#        [ 6.1,  3. ,  4.6,  1.4],
#        [ 5.8,  2.6,  4. ,  1.2],
#        [ 5. ,  2.3,  3.3,  1. ],
#        [ 5.6,  2.7,  4.2,  1.3],
#        [ 5.7,  3. ,  4.2,  1.2],
#        [ 5.7,  2.9,  4.2,  1.3],
#        [ 6.2,  2.9,  4.3,  1.3],
#        [ 5.1,  2.5,  3. ,  1.1],
#        [ 5.7,  2.8,  4.1,  1.3],
#        [ 6.3,  3.3,  6. ,  2.5],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 7.1,  3. ,  5.9,  2.1],
#        [ 6.3,  2.9,  5.6,  1.8],
#        [ 6.5,  3. ,  5.8,  2.2],
#        [ 7.6,  3. ,  6.6,  2.1],
#        [ 4.9,  2.5,  4.5,  1.7],
#        [ 7.3,  2.9,  6.3,  1.8],
#        [ 6.7,  2.5,  5.8,  1.8],
#        [ 7.2,  3.6,  6.1,  2.5],
#        [ 6.5,  3.2,  5.1,  2. ],
#        [ 6.4,  2.7,  5.3,  1.9],
#        [ 6.8,  3. ,  5.5,  2.1],
#        [ 5.7,  2.5,  5. ,  2. ],
#        [ 5.8,  2.8,  5.1,  2.4],
#        [ 6.4,  3.2,  5.3,  2.3],
#        [ 6.5,  3. ,  5.5,  1.8],
#        [ 7.7,  3.8,  6.7,  2.2],
#        [ 7.7,  2.6,  6.9,  2.3],
#        [ 6. ,  2.2,  5. ,  1.5],
#        [ 6.9,  3.2,  5.7,  2.3],
#        [ 5.6,  2.8,  4.9,  2. ],
#        [ 7.7,  2.8,  6.7,  2. ],
#        [ 6.3,  2.7,  4.9,  1.8],
#        [ 6.7,  3.3,  5.7,  2.1],
#        [ 7.2,  3.2,  6. ,  1.8],
#        [ 6.2,  2.8,  4.8,  1.8],
#        [ 6.1,  3. ,  4.9,  1.8],
#        [ 6.4,  2.8,  5.6,  2.1],
#        [ 7.2,  3. ,  5.8,  1.6],
#        [ 7.4,  2.8,  6.1,  1.9],
#        [ 7.9,  3.8,  6.4,  2. ],
#        [ 6.4,  2.8,  5.6,  2.2],
#        [ 6.3,  2.8,  5.1,  1.5],
#        [ 6.1,  2.6,  5.6,  1.4],
#        [ 7.7,  3. ,  6.1,  2.3],
#        [ 6.3,  3.4,  5.6,  2.4],
#        [ 6.4,  3.1,  5.5,  1.8],
#        [ 6. ,  3. ,  4.8,  1.8],
#        [ 6.9,  3.1,  5.4,  2.1],
#        [ 6.7,  3.1,  5.6,  2.4],
#        [ 6.9,  3.1,  5.1,  2.3],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.8,  3.2,  5.9,  2.3],
#        [ 6.7,  3.3,  5.7,  2.5],
#        [ 6.7,  3. ,  5.2,  2.3],
#        [ 6.3,  2.5,  5. ,  1.9],
#        [ 6.5,  3. ,  5.2,  2. ],
#        [ 6.2,  3.4,  5.4,  2.3],
#        [ 5.9,  3. ,  5.1,  1.8]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# ### scikit-learn中的StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScalar = StandardScaler()

# %%
standardScalar.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standardScalar.mean_
# Out:
# array([ 5.8275    ,  3.05333333,  3.71333333,  1.18166667])

# %%
standardScalar.scale_
# Out:
# array([ 0.77899107,  0.43434497,  1.71866874,  0.7462108 ])

# %%
np.mean(X_train[:,0])
# Out:
# 5.8275000000000006

# %%
np.std(X_train[:,0])
# Out:
# 0.77899106755683245

# %%
X_train
# Out:
# array([[ 5.5,  2.4,  3.8,  1.1],
#        [ 6.9,  3.1,  5.1,  2.3],
#        [ 6.1,  3. ,  4.9,  1.8],
#        [ 5.9,  3.2,  4.8,  1.8],
#        [ 6.3,  3.3,  4.7,  1.6],
#        [ 6.7,  3.1,  5.6,  2.4],
#        [ 6.8,  3.2,  5.9,  2.3],
#        [ 6.2,  2.2,  4.5,  1.5],
#        [ 7. ,  3.2,  4.7,  1.4],
#        [ 6.3,  3.4,  5.6,  2.4],
#        [ 6.2,  2.8,  4.8,  1.8],
#        [ 5. ,  3.3,  1.4,  0.2],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.7,  3. ,  5. ,  1.7],
#        [ 6.4,  3.2,  5.3,  2.3],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 5.5,  2.5,  4. ,  1.3],
#        [ 7.4,  2.8,  6.1,  1.9],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 5.9,  3. ,  5.1,  1.8],
#        [ 6.1,  2.8,  4. ,  1.3],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.8,  2.7,  4.1,  1. ],
#        [ 5.6,  2.9,  3.6,  1.3],
#        [ 5.5,  4.2,  1.4,  0.2],
#        [ 4.8,  3. ,  1.4,  0.3],
#        [ 5. ,  3.2,  1.2,  0.2],
#        [ 4.8,  3.1,  1.6,  0.2],
#        [ 6. ,  2.7,  5.1,  1.6],
#        [ 5.3,  3.7,  1.5,  0.2],
#        [ 6.6,  2.9,  4.6,  1.3],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 6.6,  3. ,  4.4,  1.4],
#        [ 4.5,  2.3,  1.3,  0.3],
#        [ 6.9,  3.2,  5.7,  2.3],
#        [ 6. ,  2.9,  4.5,  1.5],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 6.3,  2.7,  4.9,  1.8],
#        [ 6.1,  2.9,  4.7,  1.4],
#        [ 7.6,  3. ,  6.6,  2.1],
#        [ 6.4,  2.9,  4.3,  1.3],
#        [ 5.5,  2.6,  4.4,  1.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 6.7,  3.1,  4.7,  1.5],
#        [ 6.3,  2.5,  4.9,  1.5],
#        [ 7.7,  2.8,  6.7,  2. ],
#        [ 6.7,  3.1,  4.4,  1.4],
#        [ 5.6,  3. ,  4.1,  1.3],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5.4,  3. ,  4.5,  1.5],
#        [ 6. ,  3.4,  4.5,  1.6],
#        [ 6.5,  3.2,  5.1,  2. ],
#        [ 6.3,  2.3,  4.4,  1.3],
#        [ 6.9,  3.1,  4.9,  1.5],
#        [ 5. ,  3.5,  1.3,  0.3],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5.1,  3.5,  1.4,  0.2],
#        [ 7.2,  3. ,  5.8,  1.6],
#        [ 6.4,  2.8,  5.6,  2.1],
#        [ 5.7,  2.6,  3.5,  1. ],
#        [ 6.1,  2.6,  5.6,  1.4],
#        [ 5.5,  3.5,  1.3,  0.2],
#        [ 5.1,  2.5,  3. ,  1.1],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 5.6,  2.7,  4.2,  1.3],
#        [ 6.3,  2.5,  5. ,  1.9],
#        [ 7.7,  3. ,  6.1,  2.3],
#        [ 6. ,  3. ,  4.8,  1.8],
#        [ 4.6,  3.2,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5. ,  2. ,  3.5,  1. ],
#        [ 5.8,  2.8,  5.1,  2.4],
#        [ 6.4,  2.8,  5.6,  2.2],
#        [ 6.4,  3.1,  5.5,  1.8],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 6.4,  2.7,  5.3,  1.9],
#        [ 5.1,  3.4,  1.5,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 5.6,  3. ,  4.5,  1.5],
#        [ 5.8,  2.7,  3.9,  1.2],
#        [ 5.9,  3. ,  4.2,  1.5],
#        [ 6.5,  3. ,  5.8,  2.2],
#        [ 6.7,  2.5,  5.8,  1.8],
#        [ 7.7,  3.8,  6.7,  2.2],
#        [ 6.7,  3.3,  5.7,  2.1],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 6. ,  2.2,  4. ,  1. ],
#        [ 6.7,  3.3,  5.7,  2.5],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.8,  1.6,  0.2],
#        [ 5.7,  2.8,  4.1,  1.3],
#        [ 6.2,  2.9,  4.3,  1.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 6.2,  3.4,  5.4,  2.3],
#        [ 5.6,  2.8,  4.9,  2. ],
#        [ 6.1,  2.8,  4.7,  1.2],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 5.7,  3. ,  4.2,  1.2],
#        [ 6.8,  3. ,  5.5,  2.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 6.5,  2.8,  4.6,  1.5],
#        [ 7.2,  3.2,  6. ,  1.8],
#        [ 4.9,  2.4,  3.3,  1. ],
#        [ 5. ,  3.5,  1.6,  0.6],
#        [ 5.6,  2.5,  3.9,  1.1],
#        [ 5.2,  4.1,  1.5,  0.1],
#        [ 5.8,  2.6,  4. ,  1.2],
#        [ 6.5,  3. ,  5.2,  2. ],
#        [ 5.2,  3.5,  1.5,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.4,  1.5,  0.4],
#        [ 4.9,  2.5,  4.5,  1.7],
#        [ 6. ,  2.2,  5. ,  1.5],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.7,  2.9,  4.2,  1.3],
#        [ 5.7,  2.8,  4.5,  1.3]])

# %%
X_train = standardScalar.transform(X_train)

# %%
X_train
# Out:
# array([[-0.4204156 , -1.50418072,  0.05042663, -0.10944182],
#        [ 1.37678087,  0.10744148,  0.80682603,  1.49868286],
#        [ 0.34981146, -0.12279026,  0.69045689,  0.82863091],
#        [ 0.0930691 ,  0.33767322,  0.63227232,  0.82863091],
#        [ 0.60655381,  0.56790496,  0.57408775,  0.56061013],
#        [ 1.12003852,  0.10744148,  1.09774887,  1.63269325],
#        [ 1.24840969,  0.33767322,  1.27230258,  1.49868286],
#        [ 0.47818263, -1.9646442 ,  0.45771861,  0.42659974],
#        [ 1.50515205,  0.33767322,  0.57408775,  0.29258935],
#        [ 0.60655381,  0.79813671,  1.09774887,  1.63269325],
#        [ 0.47818263, -0.58325375,  0.63227232,  0.82863091],
#        [-1.06227149,  0.56790496, -1.34600303, -1.31553533],
#        [-0.93390031,  1.71906368, -1.28781847, -1.18152494],
#        [-0.03530207, -0.81348549,  0.80682603,  0.9626413 ],
#        [ 1.12003852, -0.12279026,  0.74864146,  0.69462052],
#        [ 0.73492499,  0.33767322,  0.92319516,  1.49868286],
#        [-0.93390031,  0.56790496, -1.17144933, -0.91350416],
#        [-0.4204156 , -1.27394898,  0.16679577,  0.15857896],
#        [ 2.01863675, -0.58325375,  1.38867172,  0.9626413 ],
#        [-1.31901384, -0.12279026, -1.34600303, -1.44954572],
#        [ 0.0930691 , -0.12279026,  0.80682603,  0.82863091],
#        [ 0.34981146, -0.58325375,  0.16679577,  0.15857896],
#        [-1.57575619,  1.25860019, -1.57874131, -1.31553533],
#        [-0.03530207, -0.81348549,  0.22498033, -0.24345221],
#        [-0.29204443, -0.35302201, -0.06594251,  0.15857896],
#        [-0.4204156 ,  2.63999065, -1.34600303, -1.31553533],
#        [-1.31901384, -0.12279026, -1.34600303, -1.18152494],
#        [-1.06227149,  0.33767322, -1.46237217, -1.31553533],
#        [-1.31901384,  0.10744148, -1.2296339 , -1.31553533],
#        [ 0.22144028, -0.81348549,  0.80682603,  0.56061013],
#        [-0.67715796,  1.48883194, -1.28781847, -1.31553533],
#        [ 0.99166734, -0.35302201,  0.51590318,  0.15857896],
#        [-1.19064266,  0.10744148, -1.28781847, -1.44954572],
#        [ 0.99166734, -0.12279026,  0.39953404,  0.29258935],
#        [-1.70412737, -1.73441246, -1.4041876 , -1.18152494],
#        [ 1.37678087,  0.33767322,  1.15593344,  1.49868286],
#        [ 0.22144028, -0.35302201,  0.45771861,  0.42659974],
#        [-1.19064266, -0.12279026, -1.34600303, -1.31553533],
#        [ 0.60655381, -0.81348549,  0.69045689,  0.82863091],
#        [ 0.34981146, -0.35302201,  0.57408775,  0.29258935],
#        [ 2.27537911, -0.12279026,  1.67959456,  1.23066208],
#        [ 0.73492499, -0.35302201,  0.34134947,  0.15857896],
#        [-0.4204156 , -1.04371723,  0.39953404,  0.02456857],
#        [-1.06227149,  0.79813671, -1.2296339 , -1.04751455],
#        [ 1.12003852,  0.10744148,  0.57408775,  0.42659974],
#        [ 0.60655381, -1.27394898,  0.69045689,  0.42659974],
#        [ 2.40375028, -0.58325375,  1.73777913,  1.09665169],
#        [ 1.12003852,  0.10744148,  0.39953404,  0.29258935],
#        [-0.29204443, -0.12279026,  0.22498033,  0.15857896],
#        [-1.06227149, -0.12279026, -1.2296339 , -1.31553533],
#        [-0.54878678, -0.12279026,  0.45771861,  0.42659974],
#        [ 0.22144028,  0.79813671,  0.45771861,  0.56061013],
#        [ 0.86329616,  0.33767322,  0.80682603,  1.09665169],
#        [ 0.60655381, -1.73441246,  0.39953404,  0.15857896],
#        [ 1.37678087,  0.10744148,  0.69045689,  0.42659974],
#        [-1.06227149,  1.02836845, -1.4041876 , -1.18152494],
#        [-1.31901384,  0.79813671, -1.05508019, -1.31553533],
#        [-0.93390031,  1.02836845, -1.34600303, -1.31553533],
#        [ 1.7618944 , -0.12279026,  1.21411801,  0.56061013],
#        [ 0.73492499, -0.58325375,  1.09774887,  1.23066208],
#        [-0.16367325, -1.04371723, -0.12412708, -0.24345221],
#        [ 0.34981146, -1.04371723,  1.09774887,  0.29258935],
#        [-0.4204156 ,  1.02836845, -1.4041876 , -1.31553533],
#        [-0.93390031, -1.27394898, -0.41504993, -0.10944182],
#        [-0.54878678,  1.94929542, -1.17144933, -1.04751455],
#        [-0.29204443, -0.81348549,  0.2831649 ,  0.15857896],
#        [ 0.60655381, -1.27394898,  0.74864146,  0.9626413 ],
#        [ 2.40375028, -0.12279026,  1.38867172,  1.49868286],
#        [ 0.22144028, -0.12279026,  0.63227232,  0.82863091],
#        [-1.57575619,  0.33767322, -1.34600303, -1.31553533],
#        [-1.19064266,  0.10744148, -1.28781847, -1.44954572],
#        [-1.06227149, -2.42510769, -0.12412708, -0.24345221],
#        [-0.03530207, -0.58325375,  0.80682603,  1.63269325],
#        [ 0.73492499, -0.58325375,  1.09774887,  1.36467247],
#        [ 0.73492499,  0.10744148,  1.0395643 ,  0.82863091],
#        [-1.57575619,  0.79813671, -1.34600303, -1.18152494],
#        [ 0.73492499, -0.81348549,  0.92319516,  0.9626413 ],
#        [-0.93390031,  0.79813671, -1.28781847, -1.31553533],
#        [-1.19064266,  0.10744148, -1.28781847, -1.44954572],
#        [-1.44738502,  0.33767322, -1.4041876 , -1.31553533],
#        [-0.29204443, -0.12279026,  0.45771861,  0.42659974],
#        [-0.03530207, -0.81348549,  0.1086112 ,  0.02456857],
#        [ 0.0930691 , -0.12279026,  0.2831649 ,  0.42659974],
#        [ 0.86329616, -0.12279026,  1.21411801,  1.36467247],
#        [ 1.12003852, -1.27394898,  1.21411801,  0.82863091],
#        [ 2.40375028,  1.71906368,  1.73777913,  1.36467247],
#        [ 1.12003852,  0.56790496,  1.15593344,  1.23066208],
#        [-0.93390031,  1.48883194, -1.28781847, -1.04751455],
#        [ 0.22144028, -1.9646442 ,  0.16679577, -0.24345221],
#        [ 1.12003852,  0.56790496,  1.15593344,  1.76670364],
#        [-0.54878678,  1.94929542, -1.4041876 , -1.04751455],
#        [-0.93390031,  1.71906368, -1.2296339 , -1.31553533],
#        [-0.16367325, -0.58325375,  0.22498033,  0.15857896],
#        [ 0.47818263, -0.35302201,  0.34134947,  0.15857896],
#        [-0.54878678,  0.79813671, -1.17144933, -1.31553533],
#        [ 0.47818263,  0.79813671,  0.98137973,  1.49868286],
#        [-0.29204443, -0.58325375,  0.69045689,  1.09665169],
#        [ 0.34981146, -0.58325375,  0.57408775,  0.02456857],
#        [-0.54878678,  1.48883194, -1.28781847, -1.31553533],
#        [-1.57575619,  0.10744148, -1.28781847, -1.31553533],
#        [-1.31901384,  0.79813671, -1.2296339 , -1.31553533],
#        [-0.16367325, -0.12279026,  0.2831649 ,  0.02456857],
#        [ 1.24840969, -0.12279026,  1.0395643 ,  1.23066208],
#        [-0.03530207,  2.17952716, -1.46237217, -1.31553533],
#        [ 0.86329616, -0.58325375,  0.51590318,  0.42659974],
#        [ 1.7618944 ,  0.33767322,  1.33048715,  0.82863091],
#        [-1.19064266, -1.50418072, -0.24049622, -0.24345221],
#        [-1.06227149,  1.02836845, -1.2296339 , -0.77949377],
#        [-0.29204443, -1.27394898,  0.1086112 , -0.10944182],
#        [-0.80552913,  2.40975891, -1.28781847, -1.44954572],
#        [-0.03530207, -1.04371723,  0.16679577,  0.02456857],
#        [ 0.86329616, -0.12279026,  0.8650106 ,  1.09665169],
#        [-0.80552913,  1.02836845, -1.28781847, -1.31553533],
#        [-0.16367325,  3.10045413, -1.28781847, -1.04751455],
#        [-0.54878678,  0.79813671, -1.28781847, -1.04751455],
#        [-1.19064266, -1.27394898,  0.45771861,  0.69462052],
#        [ 0.22144028, -1.9646442 ,  0.74864146,  0.42659974],
#        [-1.96086972, -0.12279026, -1.52055674, -1.44954572],
#        [-0.16367325, -0.35302201,  0.2831649 ,  0.15857896],
#        [-0.16367325, -0.58325375,  0.45771861,  0.15857896]])

# %%
X_test_standard = standardScalar.transform(X_test)

# %%
X_test_standard
# Out:
# array([[ 0.60655381, -0.35302201,  1.09774887,  0.82863091],
#        [-1.83249855,  0.33767322, -1.4041876 , -1.31553533],
#        [-0.03530207, -0.81348549,  0.80682603,  0.9626413 ],
#        [-0.16367325, -1.27394898,  0.74864146,  1.09665169],
#        [-1.06227149, -1.73441246, -0.24049622, -0.24345221],
#        [-1.44738502,  0.33767322, -1.2296339 , -1.31553533],
#        [ 2.66049264,  1.71906368,  1.56322543,  1.09665169],
#        [ 0.60655381, -0.58325375,  0.80682603,  0.42659974],
#        [ 0.60655381,  0.56790496,  1.33048715,  1.76670364],
#        [-0.4204156 , -1.50418072, -0.00775794, -0.24345221],
#        [-0.93390031,  1.71906368, -1.05508019, -1.04751455],
#        [ 0.73492499,  0.33767322,  0.45771861,  0.42659974],
#        [-1.06227149,  1.25860019, -1.34600303, -1.31553533],
#        [-0.16367325,  1.71906368, -1.17144933, -1.18152494],
#        [ 1.37678087,  0.10744148,  0.98137973,  1.23066208],
#        [ 0.86329616, -0.12279026,  1.0395643 ,  0.82863091],
#        [ 2.40375028, -1.04371723,  1.85414827,  1.49868286],
#        [ 1.24840969, -0.58325375,  0.63227232,  0.29258935],
#        [ 1.7618944 ,  1.25860019,  1.38867172,  1.76670364],
#        [-0.80552913,  0.79813671, -1.34600303, -1.31553533],
#        [ 1.63352322, -0.12279026,  1.27230258,  1.23066208],
#        [-0.4204156 , -1.73441246,  0.16679577,  0.15857896],
#        [-1.83249855, -0.12279026, -1.4041876 , -1.31553533],
#        [ 1.12003852, -0.12279026,  0.8650106 ,  1.49868286],
#        [ 0.34981146, -0.12279026,  0.51590318,  0.29258935],
#        [-1.83249855, -0.35302201, -1.34600303, -1.31553533],
#        [-0.93390031,  1.02836845, -1.34600303, -1.18152494],
#        [ 1.89026558, -0.35302201,  1.50504086,  0.82863091],
#        [-1.06227149,  0.79813671, -1.28781847, -1.31553533],
#        [-0.80552913, -0.81348549,  0.1086112 ,  0.29258935]])

# %%
np.mean(X_test_standard[:,0])
# Out:
# 0.10162718157341215

# %%
np.std(X_test_standard[:,0])
# Out:
# 1.2664510399599134

# %% [markdown]
# 使用归一化后的数据进行knn分类

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
knn_clf.score(X_test_standard, y_test)
# Out:
# 0.96666666666666667

# %% [markdown]
# 注意，此时不能传入没有归一化的数据！

# %%
knn_clf.score(X_test, y_test)
# Out:
# 0.43333333333333335

# %% [markdown]
# ### 实现我们自己的standardScaler
